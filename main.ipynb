# %% [markdown]
# # RBSO

# %% [markdown]
# ## Environment Simulation

# %% [markdown]
# ### Create a initial environment

# %%
import environment as ENV

env = ENV.Environment(area=(10, 10), num_obstacles=50, num_targets=2, num_robots=5, a=1, r=2, threshold=0.5)
env.measure()
env.plot()
